# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
xs=np.linspace(1,2,100)
ys=xs**5.59
plt.plot(xs,ys)
plt.xlabel('$\\frac{T}{T_{\\bigodot}}$',fontsize=18)
plt.ylabel('$\\frac{L}{L_{\\bigodot}}$',fontsize=18)
# Out:
# Text(0, 0.5, '$\\frac{L}{L_{\\bigodot}}$')

# %%
a=np.array([1.1,1.2,1.5,2])
b=a**1.3*5778
b
# Out:
# array([ 6540.15480573,  7323.40677317,  9788.0498896 , 14227.10484061])

# %%
0.002897/b
# Out:
# array([4.42955876e-07, 3.95580922e-07, 2.95973154e-07, 2.03625406e-07])

# %%
t=0.1*2*10**30*0.0007*(3*10**8)**2/(3.828*10**26)/86400/365
t
# Out:
# 1043739234.5753233

# %%
t/a
# Out:
# array([9.48853850e+08, 8.69782695e+08, 6.95826156e+08, 5.21869617e+08])
